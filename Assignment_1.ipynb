# %% [markdown]
# <a href="https://colab.research.google.com/github/afrahnaaz/NLP/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3. QUESTION

# %%
#import nltk
#nltk.download('WordNet')

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()
words = ["cats", "trouble", "troubling", "troubled", "having", "corriendo", "at", "was"]
for w in words:
  rootWord1=ps.stem(w)
  print('Stem word:', rootWord1)
  rootWord2=lemmatizer.lemmatize(w)
  print('Lemma word:', rootWord2)
# Out:
# Stem word: cat
# Lemma word: cat
# Stem word: troubl
# Lemma word: trouble
# Stem word: troubl
# Lemma word: troubling
# Stem word: troubl
# Lemma word: troubled
# Stem word: have
# Lemma word: having
# Stem word: corriendo
# Lemma word: corriendo
# Stem word: at
# Lemma word: at
# Stem word: wa
# Lemma word: wa

# %% [markdown]
# 8. QUESTION

# %%
import nltk
import re
def word_extraction(sentence):
    ignore = ['a', "the", "is"]
    words = re.sub("[^\w]", " ",  sentence).split()
    cleaned_text = [w.lower() for w in words if w not in ignore]
    return cleaned_text

# %%
import pandas as pd
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
text = "Text Summarization is one of those applications of Natural Language Processing (NLP) which is bound to have a huge impact on our lives. With growing digital media and ever-growing publishing – who has the time to go through entire articles / documents / books to decide whether they are useful or not? Thankfully – this technology is already here."
text = word_extraction(text)
data = pd.DataFrame(columns=['Word', 'Frequency', 'Stem', 'Lemma'])
for word in set(text):
    data.loc[len(data.index)] = [word, text.count(word), stemmer.stem(word), lemmatizer.lemmatize(word)]
data
# Out:
#              Word Frequency       Stem          Lemma
# 0       documents         1   document       document
# 1            they         1       they           they
# 2            here         1       here           here
# 3         through         1    through        through
# 4      processing         1    process     processing
# 5          decide         1      decid         decide
# 6              to         3         to             to
# 7    applications         1     applic    application
# 8        articles         1     articl        article
# 9            this         1        thi           this
# 10          media         1      media         medium
# 11           time         1       time           time
# 12             go         1         go             go
# 13        whether         1    whether        whether
# 14            are         1        are            are
# 15             on         1         on             on
# ...
